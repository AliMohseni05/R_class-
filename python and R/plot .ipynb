# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
#---------------------------------------#
#                 plot                  #
#---------------------------------------#
#---------------data part----------------
"""call data from getcwd to chadir by using os 
"""
#import os
#print(os.getcwd()) 
#os.chdir("G:\R CLASS practice\python and R\python code")
#df=pd.read_csv("Boxplot_data.csv")

"""call data directly 
"""
df=pd.read_csv("G:\R CLASS practice\python and R\python code\Boxplot_data.csv")
df=pd.DataFrame(df)
df=df.sort_values(by=["DH.WW015"],ascending=False)#col DH.WW015 in this exame
#np_arr=df.to_numpy()
df=df.sort_values(by="DH.WW015")
np_arr=df.values
x1= np_arr[:,0] #CHOSE 1 col time
y1= np_arr[:,1] # 2 col DH.WW015
y2= np_arr[:,2] # 3 col
y3= np_arr[:,3] # 4 col
#y4= np_arr[:,4] # 5 col
image1=plt.figure(figsize=(10,5),dpi=(100),facecolor=("#FBFCFC")) #make image 
axes=image1.add_axes([0.1,0.1,0.8,0.8]) # sice of axes
axes.set_facecolor('#17202A') 
axes.set_title("bioinformatic data")
axes.set_xlabel("time")
axes.set_ylabel("e")
#axes.plot(x,y,label="y site",marker = 'o',mfc = 'r') #make marke in line 
axes.plot(x1,y2,label="b data")
axes.plot(x1,y3,label="c data")
#axes.plot(x,c,label="c site",marker = 'o',mfc = 'g')
#axes.plot(x,f,label="f site",marker = 'o',mfc = 'y')
axes.legend(loc=0) #this one showe us the labels in the best place
